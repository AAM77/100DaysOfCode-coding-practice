# %%
# What is a module?
# Modules are just .py scripts that you call 
# in another .py script
#
# Then, what is a package?
# A package is a collection of modules
# We let python know that a collection
# of modules is part of a package by using
# placing a __init__.py script (file) inside
# of a folder to let python know to treat
# all of the scripts in that folder as part
# of a package.


# let's assume we have a file with a script
# we want to call (this is our module).
# We will call this 'mymodule.py'
# and, we will have a function inside it
# called 'my_func()'.

# then, let's assume we have a file where we
# are calling our mymodule.py script.

# assuming that they are within the same
# folder, the syntax for calling the module
# is:

##
##
##
##

#-------------------------------

# from mymodule import my_func

# my_func()

#-------------------------------

##
##
##
##

# Here, we called my_func from mymodule.py
# inside of another file (myprogram.py).

# To create a package:
# (1) we create a folder.
# (2) add a file called __init__.py (it doesn't need any text inside of it. Its presence is enough to let Python know that all the files in that folder are part of a package.)
# (3) add .py scripts/files (modules) that we want to be part of a package

# To call a package inside of a program file
# that is outside of the package, we type:

##
##
##
##

#-------------------------------

# from MyMainPackage import somemainscript
# from MyMainPackage.SubPackage import mysubscript

# somemainscript.report_main()
# mysubscript.sub_report()

#-------------------------------

##
##
##
##
